# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./dataset_Facebook (2).csv', sep=';')
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
s1 = data[data['Page total likes'] > 130000]
s1.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
s1.shape
# Out:
# (243, 19)

# %%
s2 = data[data['Type'] == 'Status']
s2.shape
# Out:
# (45, 19)

# %%
s2.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
s3 = data[(data['Type'] == 'Status') & (data['Lifetime Post Consumptions'] > 2000)]
s3.shape
# Out:
# (25, 19)

# %%
s3.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 10            139441  Status         2          12             5         10
# 26            138458  Status         2          12             5         11
# 38            138895  Status         2          12             7          9
# 40            138895  Status         2          12             6         11
# 46            138353  Status         1          12             3         11
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 10   0.0                      21744                            42334
# 26   0.0                      19552                            34143
# 38   0.0                      17576                            33058
# 40   0.0                      13280                            24198
# 46   0.0                      16576                            30612
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
s4 = data[(data['Type'] == 'Video') & (data['Post Hour'] == 10)]
s4.shape
# Out:
# (1, 19)

# %%
s4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 183                    2080                     1956
#
#      Lifetime Post Consumptions  \
# 183                        3253
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 183                                              32033
#
#      Lifetime Post reach by people who like your Page  \
# 183                                             15744
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 183                                               1376
#
#      comment   like  share  Total Interactions
# 183        6  345.0  121.0                 472

# %%
s5 = data[(data['Type'] == 'Status') & (data['Category'] > 2)]
s3.shape
# Out:
# (25, 19)

# %%
Time_data = data.iloc[: , 3:6]
Time_data
# Out:
#      Post Month  Post Weekday  Post Hour
# 0            12             4          3
# 1            12             3         10
# 2            12             3          3
# 3            12             2         10
# 4            12             2          3
# ..          ...           ...        ...
# 494           1             7         10
# 495           1             7          2
# 496           1             5          8
# 497           1             5          2
# 498           1             4         11
#
# [495 rows x 3 columns]

# %%
data[:251].shape
# Out:
# (251, 19)

# %%
merge_ds = pd.merge(s3 , s5 , on="Type")

# %%
merge_ds.head()
# Out:
#    Page total likes_x    Type  Category_x  Post Month_x  Post Weekday_x  \
# 0              139441  Status           2            12               5
# 1              139441  Status           2            12               5
# 2              139441  Status           2            12               5
# 3              139441  Status           2            12               5
# 4              138458  Status           2            12               5
#
#    Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# 0           10     0.0                        21744
# 1           10     0.0                        21744
# 2           10     0.0                        21744
# 3           10     0.0                        21744
# 4           11     0.0                        19552
#
#    Lifetime Post Total Impressions_x  Lifetime Engaged Users_x  ...  \
# 0                              42334                      4258  ...
# 1                              42334                      4258  ...
# ...

# %%
data.sort_values("Lifetime Post Consumers" , ascending = True)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195   Photo         1           3             5          4
# 21             138414   Photo         1          12             7         10
# 76             137893   Photo         1          11             3          2
# 430            100732    Link         1           3             7         14
# 417            104070   Photo         1           3             3         10
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 172            135195  Status         2           9             1         10
# 38             138895  Status         2          12             7          9
# 142            136013  Status         2          10             3          2
# 446             96749   Photo         1           3             1          2
#
# ...

# %%
pivot = pd.pivot_table(data,index='Post Month',columns = 'Category',values = 'like',aggfunc = "sum")

# %%
pivot
# Out:
# Category         1       2       3
# Post Month
# 1            918.0   482.0  1581.0
# 2           1547.0   376.0  3094.0
# 3           2118.0    80.0   794.0
# 4           2708.0  1656.0  4773.0
# 5            773.0  1263.0  5962.0
# 6           1969.0  1198.0  3380.0
# 7           2602.0  8432.0  3137.0
# 8           1755.0  1469.0  3523.0
# 9           2651.0  2725.0  2920.0
# 10          2936.0  4701.0  1593.0
# 11          5082.0   392.0  1478.0
# 12          1640.0  5567.0  1402.0

# %%
pivot_t = pivot.T

# %%
pivot_t
# Out:
# Post Month      1       2       3       4       5       6       7       8   \
# Category
# 1            918.0  1547.0  2118.0  2708.0   773.0  1969.0  2602.0  1755.0
# 2            482.0   376.0    80.0  1656.0  1263.0  1198.0  8432.0  1469.0
# 3           1581.0  3094.0   794.0  4773.0  5962.0  3380.0  3137.0  3523.0
#
# Post Month      9       10      11      12
# Category
# 1           2651.0  2936.0  5082.0  1640.0
# 2           2725.0  4701.0   392.0  5567.0
# 3           2920.0  1593.0  1478.0  1402.0

# %%
data_t = data.T
data_t.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    489    490    491    492  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85979
# Type               Photo  Status   Photo  ...  Photo  Photo  Photo   Link
# Category               3       2       3  ...      3      3      3      1
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      7      6      6      5
#
#                     493    494    495    496    497    498
# ...

# %%
pd.melt(data , id_vars = ['Type'] , value_vars = ['Category'])
# Out:
#        Type  variable  value
# 0     Photo  Category      2
# 1    Status  Category      2
# 2     Photo  Category      3
# 3     Photo  Category      2
# 4     Photo  Category      2
# ..      ...       ...    ...
# 490   Photo  Category      3
# 491   Photo  Category      3
# 492   Photo  Category      2
# 493   Photo  Category      1
# 494   Photo  Category      3
#
# [495 rows x 3 columns]

# %%
data_p = pd.melt(data , id_vars = ['Type'] , value_vars = ['Category' , 'comment'])
data_p.tail()
# Out:
#       Type variable  value
# 985  Photo  comment     10
# 986  Photo  comment      5
# 987  Photo  comment      0
# 988  Photo  comment      4
# 989  Photo  comment      7

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
plt.barh(data['Category'],data['like'])
plt.ylabel("Category")
plt.xlabel("likes")
# Out:
# Text(0.5, 0, 'likes')

# %%
val = data['Type'].value_counts()
plt.pie(val , labels = val.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x167d8021010>,
# ...
#  [Text(-0.9808983109261807, 0.4978338112484586, 'Photo'),
#   Text(0.8732196645762106, -0.6689450032681391, 'Status'),
#   Text(1.0714131191866294, -0.24914639879953646, 'Link'),
#   Text(1.098914635081412, -0.04885309410761325, 'Video')])

# %%
plt.bar(data["Post Month"] , data["comment"])
plt.ylabel("Comment Count")
plt.xlabel("Post Month")
# Out:
# Text(0.5, 0, 'Post Month')
